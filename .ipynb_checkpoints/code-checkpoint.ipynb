# %% [markdown]
# # Control de un player de vídeo a través de gestos

# %% [markdown]
# ## Paquetes necesarios

# %%
import cv2
import mediapipe as mp

# %% [markdown]
# ![Hand landmarks.]("C:/Users/34611/OneDrive/Escritorio/GTDM/Tercero/Imagen/Proyecto/Control-de-player-via-gestos/images/hand_landmarks.png")

# %%
def get_finger_states(hand_landmarks):
    fingers = []

    # Pulgar (compara X en lugar de Y porque el pulgar se mueve lateralmente)
    if hand_landmarks.landmark[4].x > hand_landmarks.landmark[3].x:
        fingers.append(1)  # Extendido
    else:
        fingers.append(0)  # Doblado

    # Resto de los dedos: Índice, Medio, Anular, Meñique
    tips = [8, 12, 16, 20]
    pips = [6, 10, 14, 18]

    for tip, pip in zip(tips, pips):
        if hand_landmarks.landmark[tip].y < hand_landmarks.landmark[pip].y:
            fingers.append(1)
        else:
            fingers.append(0)

    return fingers  # [pulgar, índice, medio, anular, meñique]

# %%
# Detecta gesto: Mano abierta o puño
def detect_custom_gesture(fingers):
    # fingers = [pulgar, índice, medio, anular, meñique]
    #if fingers == [1, 1, 0, 0, 0]:
     #   return "L"
    #elif fingers == [0, 1, 1, 0, 0]:
      #  return "V"
    if fingers == [0, 1, 0, 0, 1]:
        return "Rock"
    #elif fingers == [0, 0, 0, 0, 0]:
     #   return "Puño"
    if fingers == [1, 1, 1, 1, 1]:
        return "Palma"
    else:
        return "Unknown"

# %%
from selenium import webdriver
from selenium.webdriver.chrome.options import Options
import time

# Configurar Selenium (modo visible o headless)
options = Options()
# options.add_argument('--headless')  # descomenta si quieres que sea invisible
options.add_argument("--autoplay-policy=no-user-gesture-required")

#WebDriverWait(driver, 10).until(
#    lambda d: d.execute_script("return video.readyState;") == 4
#)
# Out:
# ---------------------------------------------------------------------------
# NoSuchWindowException                     Traceback (most recent call last)
# Cell In[7], line 13
#      10 driver.get("https://areyousure.wavedash.com/player.html?content=Video1/glass_half.mpd")
#      12 from selenium.webdriver.support.ui import WebDriverWait
# ---> 13 ready = driver.execute_script("return video.readyState;")
#      14 print("Video readyState:", ready)
#
# File ~\anaconda3\envs\Imagen\Lib\site-packages\selenium\webdriver\remote\webdriver.py:544, in WebDriver.execute_script(self, script, *args)
#     541 converted_args = list(args)
#     542 command = Command.W3C_EXECUTE_SCRIPT
# --> 544 return self.execute(command, {"script": script, "args": converted_args})["value"]
#
# File ~\anaconda3\envs\Imagen\Lib\site-packages\selenium\webdriver\remote\webdriver.py:447, in WebDriver.execute(self, driver_command, params)
#     445 response = self.command_executor.execute(driver_command, params)
#     446 if response:
# --> 447     self.error_handler.check_response(response)
#     448     response["value"] = self._unwrap_value(response.get("value", None))
#     449     return response
#
# File ~\anaconda3\envs\Imagen\Lib\site-packages\selenium\webdriver\remote\errorhandler.py:232, in ErrorHandler.check_response(self, response)
#     230         alert_text = value["alert"].get("text")
#     231     raise exception_class(message, screen, stacktrace, alert_text)  # type: ignore[call-arg]  # mypy is not smart enough here
# --> 232 raise exception_class(message, screen, stacktrace)
#
# NoSuchWindowException: Message: no such window: target window already closed
# from unknown error: web view not found
#   (Session info: chrome=136.0.7103.114)
# Stacktrace:
# 	GetHandleVerifier [0x00007FF6EE18CF45+75717]
# 	GetHandleVerifier [0x00007FF6EE18CFA0+75808]
# 	(No symbol) [0x00007FF6EDF58F9A]
# 	(No symbol) [0x00007FF6EDF31B41]
# 	(No symbol) [0x00007FF6EDFDEC2E]
# 	(No symbol) [0x00007FF6EDFFECC2]
# 	(No symbol) [0x00007FF6EDFD7153]
# 	(No symbol) [0x00007FF6EDFA0421]
# 	(No symbol) [0x00007FF6EDFA11B3]
# 	GetHandleVerifier [0x00007FF6EE48D71D+3223453]
# 	GetHandleVerifier [0x00007FF6EE487CC2+3200322]
# 	GetHandleVerifier [0x00007FF6EE4A5AF3+3322739]
# 	GetHandleVerifier [0x00007FF6EE1A6A1A+180890]
# 	GetHandleVerifier [0x00007FF6EE1AE11F+211359]
# 	GetHandleVerifier [0x00007FF6EE195294+109332]
# 	GetHandleVerifier [0x00007FF6EE195442+109762]
# 	GetHandleVerifier [0x00007FF6EE17BA59+4825]
# 	BaseThreadInitThunk [0x00007FFC10547374+20]
# 	RtlUserThreadStart [0x00007FFC11A3CC91+33]

# %%
import pyautogui

# %%
driver = webdriver.Chrome(options=options)
driver.get("https://areyousure.wavedash.com")

# %%
def control(modo,pos_anterior,punta_indice,mov):
    global driver
    global previousMilis
    if modo == 'navegación':
        screen_w, screen_h = pyautogui.size()  #Dimensiones de la pantalla en píxeles
        if pos_anterior != None:
            if punta_indice.y-pos_anterior[8].y > 0.1:
                pyautogui.click()
                from selenium.webdriver.support.ui import WebDriverWait
                actual_url = driver.current_url 
                print(actual_url)
                if actual_url != 'areyousure.wavedash.com':
                    return 'player'
            else:  #Para que no haga el click y el movimiento a la vez
                pos_X = int(punta_indice.x*screen_w)
                pos_Y = int(punta_indice.y*screen_h)
                pyautogui.moveTo(pos_X, pos_Y)
        return 'navegación'
    else:
        currentMilis = time.time()
        if pos_anterior != None and currentMilis-previousMilis>0.5:
            if punta_indice.x-pos_anterior[8].x > 0.04:
                print('adelantar')
                mov = 'der-izq'
                driver.execute_script("video.currentTime += 5;")
            elif punta_indice.x-pos_anterior[8].x < -0.04:
                print('atrasar')
                mov = 'izq-der'
                driver.execute_script("video.currentTime -= 5;")
            if punta_indice.y-pos_anterior[8].y < -0.1:
                print('subir volumen')
                mov = 'abajo-arriba'
                driver.execute_script("if (video.volume <= 0.9){video.volume += 0.1}else {video.volume=1};")
            elif punta_indice.y-pos_anterior[8].y > 0.1:
                print('bajar volumen')
                mov = 'arriba-abajo'
                driver.execute_script("if (video.volume >= 0.1){video.volume -= 0.1}else {video.volume=0};")
            if mov == 'Palma':
                print('parar')
                driver.execute_script("video.pause();")
            elif mov == 'Rock':
                print('continuar')
                driver.execute_script("video.play();")
                
            if mov != 'Unknown':
                print('indice y:',punta_indice.y)
                print('movimiento punta_indice x', punta_indice.x-pos_anterior[8].x ,punta_indice.y-pos_anterior[8].y)
                previousMilis = currentMilis
        cv2.putText(image, f'Gesture: {mov}', (10, 30), cv2.FONT_HERSHEY_SIMPLEX, 1, (255, 0, 0), 2)
        return 'player'

# %%
import time
mp_hands   = mp.solutions.hands
mp_drawing = mp.solutions.drawing_utils
cap = cv2.VideoCapture(1)  #CAMBIAR A 0 SI NO VA
pos_anterior = None
modo = 'navegación'
currentMilis = 0
previousMilis = 0
with mp_hands.Hands(max_num_hands=1, min_detection_confidence=0.7) as hands:
    while cap.isOpened():
        ret, frame = cap.read()
        if not ret:
            print('No se puede leer la cámara')
            break

        try:
            image = cv2.cvtColor(frame, cv2.COLOR_BGR2RGB)
            image.flags.writeable = False
            results = hands.process(image)
            image.flags.writeable = True
            image = cv2.cvtColor(image, cv2.COLOR_RGB2BGR)

            if results.multi_hand_landmarks:
                for hand_landmarks in results.multi_hand_landmarks:
                    mp_drawing.draw_landmarks(image, hand_landmarks, mp_hands.HAND_CONNECTIONS)
                    punta_indice = hand_landmarks.landmark[8]
                    dedos = get_finger_states(hand_landmarks)
                    mov = detect_custom_gesture(dedos) # Detecta el gesto de la palma 
                    modo = control(modo,pos_anterior,punta_indice,mov)
                    pos_anterior = hand_landmarks.landmark
                    
            cv2.imshow('Hand Gesture Recognition', image)
        except Exception as e:
            import traceback
            traceback.print_exc()
            
        
        if cv2.waitKey(1) == ord('q'):
            break

cap.release()
cv2.destroyAllWindows()
# Out:
# https://areyousure.wavedash.com/player.html?content=Video2/master.m3u8
# adelantar
# subir volumen
# indice y: 0.26160505414009094
# movimiento punta_indice x 0.041307538747787476 -0.29131147265434265
# parar
# indice y: 0.24474970996379852
# movimiento punta_indice x 0.002490699291229248 0.003705129027366638
# parar
# indice y: 0.25104379653930664
# movimiento punta_indice x 0.003415524959564209 0.00279843807220459
# parar
# indice y: 0.2686472237110138
# movimiento punta_indice x 8.207559585571289e-05 -0.00032576918601989746
# adelantar
# indice y: 0.2447175830602646
# movimiento punta_indice x 0.04702126979827881 0.0190725177526474
# parar
# indice y: 0.2890161871910095
# movimiento punta_indice x 0.0003236532211303711 -0.0002957582473754883
# parar
# indice y: 0.28492671251296997
# movimiento punta_indice x -0.004786491394042969 -0.0029866695404052734
# parar
# indice y: 0.2633823752403259
# movimiento punta_indice x 0.02818167209625244 0.007948338985443115
# parar
# indice y: 0.32576942443847656
# movimiento punta_indice x 0.011227071285247803 -0.0009452700614929199
# atrasar
# indice y: 0.228601336479187
# movimiento punta_indice x -0.06656545400619507 -0.01390036940574646
# parar
# indice y: 0.3167450428009033
# movimiento punta_indice x 0.0228273868560791 0.0122147798538208
# parar
# indice y: 0.27942824363708496
# movimiento punta_indice x -0.035147905349731445 -0.018527507781982422
# parar
# indice y: 0.30444538593292236
# movimiento punta_indice x 0.020214319229125977 0.017159998416900635
# parar
# indice y: 0.37404555082321167
# movimiento punta_indice x 0.01151895523071289 0.002243220806121826
# parar
# indice y: 0.20432624220848083
# movimiento punta_indice x 0.009777218103408813 0.004940301179885864
# parar
# indice y: 0.4129942059516907
# movimiento punta_indice x 0.013970553874969482 -0.0025669336318969727
# parar
# indice y: 0.29338759183883667
# movimiento punta_indice x -0.03796994686126709 -0.01938527822494507
# parar
# indice y: 0.28914564847946167
# movimiento punta_indice x 0.032774269580841064 0.030641794204711914
# parar
# indice y: 0.30366504192352295
# movimiento punta_indice x 0.0017991065979003906 0.0028917789459228516
# parar
# indice y: 0.21161481738090515
# movimiento punta_indice x -0.0007002055644989014 0.0044367313385009766
# parar
# indice y: 0.3128514885902405
# movimiento punta_indice x 0.022809326648712158 0.009603738784790039
# parar
# indice y: 0.29715168476104736
# movimiento punta_indice x -0.006304919719696045 -0.003207087516784668
# atrasar
# indice y: 0.20556914806365967
# movimiento punta_indice x -0.05993276834487915 -0.019035011529922485
# parar
# indice y: 0.3190942406654358
# movimiento punta_indice x 0.029963254928588867 0.007101655006408691
# parar
# indice y: 0.3384879231452942
# movimiento punta_indice x -0.004998445510864258 -0.004216492176055908
# adelantar
# indice y: 0.2964099645614624
# movimiento punta_indice x 0.05688071250915527 0.034383296966552734
# parar
# indice y: 0.366266667842865
# movimiento punta_indice x 0.0025963187217712402 -0.0019380450248718262
# atrasar
# indice y: 0.27904951572418213
# movimiento punta_indice x -0.07214224338531494 -0.030032098293304443
# parar
# indice y: 0.38314974308013916
# movimiento punta_indice x 0.017991244792938232 0.014648497104644775
# parar
# indice y: 0.4033302962779999
# movimiento punta_indice x 0.006205558776855469 0.000344693660736084
# parar
# indice y: 0.29272013902664185
# movimiento punta_indice x 0.024451613426208496 0.015556693077087402
# parar
# indice y: 0.44229239225387573
# movimiento punta_indice x 0.009025096893310547 -0.006694912910461426
# parar
# indice y: 0.2627021074295044
# movimiento punta_indice x -0.0303075909614563 -0.0023565590381622314
# parar
# indice y: 0.3302268385887146
# movimiento punta_indice x -0.0012125968933105469 -0.0066567063331604
# bajar volumen
# indice y: 0.403744101524353
# movimiento punta_indice x -0.01600712537765503 0.10198366641998291
# bajar volumen
# indice y: 0.4847072660923004
# movimiento punta_indice x -0.022229820489883423 0.16181227564811707
# bajar volumen
# indice y: 0.4839073121547699
# movimiento punta_indice x -0.009943664073944092 0.10402420163154602
# bajar volumen
# indice y: 0.4665032923221588
# movimiento punta_indice x -0.029540270566940308 0.15316525101661682
# atrasar
# indice y: 0.26075297594070435
# movimiento punta_indice x -0.07555395364761353 -0.02336937189102173
# parar
# indice y: 0.27116119861602783
# movimiento punta_indice x 0.023725569248199463 -0.05742660164833069
# parar
# indice y: 0.18892031908035278
# movimiento punta_indice x 0.0008307099342346191 -0.0004107058048248291
# parar
# indice y: 0.1196340024471283
# movimiento punta_indice x -0.0042185187339782715 0.002063453197479248
# parar
# indice y: 0.1348755657672882
# movimiento punta_indice x -6.210803985595703e-05 0.0042906105518341064
# parar
# indice y: 0.11176100373268127
# movimiento punta_indice x -0.004652261734008789 -0.001559913158416748
# parar
# indice y: 0.11898490786552429
# movimiento punta_indice x 0.0012996196746826172 -0.0024208426475524902
# parar
# indice y: 0.10393267869949341
# movimiento punta_indice x 0.008482277393341064 -0.003664463758468628
# parar
# indice y: 0.14010389149188995
# movimiento punta_indice x 0.006581723690032959 0.00664152204990387
# parar
# indice y: 0.17565949261188507
# movimiento punta_indice x -0.006885886192321777 0.0050354450941085815
# parar
# indice y: 0.21959733963012695
# movimiento punta_indice x -0.004810452461242676 -0.0027276724576950073
# adelantar
# indice y: 0.16963839530944824
# movimiento punta_indice x 0.040693432092666626 0.010874420404434204
# parar
# indice y: 0.24450156092643738
# movimiento punta_indice x 0.007052600383758545 0.0004730820655822754
# parar
# indice y: 0.24181735515594482
# movimiento punta_indice x -0.0005420446395874023 -0.0013475865125656128
# parar
# indice y: 0.1336110234260559
# movimiento punta_indice x 0.01652902364730835 0.015216410160064697
# parar
# indice y: 0.2442484349012375
# movimiento punta_indice x 0.01825273036956787 0.002908363938331604
# parar
# indice y: 0.1966896951198578
# movimiento punta_indice x 0.011594176292419434 0.010318100452423096
# atrasar
# indice y: 0.2883709967136383
# movimiento punta_indice x -0.042511820793151855 -0.020775318145751953
# atrasar
# indice y: 0.27365028858184814
# movimiento punta_indice x -0.050665199756622314 -0.026077568531036377
# adelantar
# bajar volumen
# indice y: 0.42185747623443604
# movimiento punta_indice x 0.11050534248352051 0.1482071876525879
# adelantar
# bajar volumen
# indice y: 0.5010076761245728
# movimiento punta_indice x 0.043755948543548584 0.1261327862739563
# atrasar
# subir volumen
# indice y: 0.2778942584991455
# movimiento punta_indice x -0.15332120656967163 -0.14103418588638306
# parar
# indice y: 0.33665260672569275
# movimiento punta_indice x 0.0067819952964782715 -0.013837844133377075
# parar
# indice y: 0.2613551616668701
# movimiento punta_indice x 0.020676344633102417 0.003969967365264893
# parar
# indice y: 0.2957436740398407
# movimiento punta_indice x -0.001827150583267212 0.0018296539783477783
# parar
# indice y: 0.26892292499542236
# movimiento punta_indice x -0.02967873215675354 0.01863369345664978

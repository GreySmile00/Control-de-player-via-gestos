# %% [markdown]
# # Control de un player de vídeo a través de gestos

# %% [markdown]
# ## Paquetes necesarios

# %%
import cv2
import mediapipe as mp

# %% [markdown]
# ![Hand landmarks.]("C:/Users/34611/OneDrive/Escritorio/GTDM/Tercero/Imagen/Proyecto/Control-de-player-via-gestos/images/hand_landmarks.png")

# %%
mp_hands   = mp.solutions.hands
mp_drawing = mp.solutions.drawing_utils

def get_finger_states(hand_landmarks):
    fingers = []

    # Pulgar (compara X en lugar de Y porque el pulgar se mueve lateralmente)
    if hand_landmarks.landmark[4].x < hand_landmarks.landmark[3].x:
        fingers.append(1)  # Extendido
    else:
        fingers.append(0)  # Doblado

    # Resto de los dedos: Índice, Medio, Anular, Meñique
    tips = [8, 12, 16, 20]
    pips = [6, 10, 14, 18]

    for tip, pip in zip(tips, pips):
        if hand_landmarks.landmark[tip].y < hand_landmarks.landmark[pip].y:
            fingers.append(1)
        else:
            fingers.append(0)

    return fingers  # [pulgar, índice, medio, anular, meñique]

# Detecta gesto: Mano abierta o puño
def detect_custom_gesture(fingers):
    # fingers = [pulgar, índice, medio, anular, meñique]
    if fingers == [1, 1, 0, 0, 0]:
        return "L"
    elif fingers == [0, 1, 1, 0, 0]:
        return "V"
    elif fingers == [0, 1, 0, 0, 1]:
        return "Rock"
    elif fingers == [0, 0, 0, 0, 0]:
        return "Puño"
    elif fingers == [1, 1, 1, 1, 1]:
        return "Palma"
    else:
        return "Unknown"

# Captura
cap = cv2.VideoCapture(1)

with mp_hands.Hands(max_num_hands=1, min_detection_confidence=0.7) as hands:
    while cap.isOpened():
        ret, frame = cap.read()
        if not ret:
            break

        image = cv2.cvtColor(frame, cv2.COLOR_BGR2RGB)
        image.flags.writeable = False
        results = hands.process(image)

        image.flags.writeable = True
        image = cv2.cvtColor(image, cv2.COLOR_RGB2BGR)

        if results.multi_hand_landmarks:
            for hand_landmarks in results.multi_hand_landmarks:
                mp_drawing.draw_landmarks(image, hand_landmarks, mp_hands.HAND_CONNECTIONS)

                fingers = get_finger_states(hand_landmarks)
                gesture = detect_custom_gesture(fingers)
                cv2.putText(image, f'Gesture: {gesture}', (10, 30), cv2.FONT_HERSHEY_SIMPLEX, 1, (255, 0, 0), 2)

        cv2.imshow('Hand Gesture Recognition', image)
        if cv2.waitKey(1) == ord('q'):
            break

cap.release()
cv2.destroyAllWindows()

# %%
from selenium import webdriver
from selenium.webdriver.chrome.options import Options
import time

# Configurar Selenium (modo visible o headless)
options = Options()
# options.add_argument('--headless')  # descomenta si quieres que sea invisible
driver = webdriver.Chrome(options=options)
driver.get("http://areyousure.wavedash.com")
time.sleep(5)

# Reproducir
driver.execute_script("player.play();")
# Out:
# ---------------------------------------------------------------------------
# JavascriptException                       Traceback (most recent call last)
# Cell In[9], line 13
#      10 time.sleep(5)
#      12 # Reproducir
# ---> 13 driver.execute_script("player.play();")
#
# File ~\anaconda3\envs\Imagen\Lib\site-packages\selenium\webdriver\remote\webdriver.py:544, in WebDriver.execute_script(self, script, *args)
#     541 converted_args = list(args)
#     542 command = Command.W3C_EXECUTE_SCRIPT
# --> 544 return self.execute(command, {"script": script, "args": converted_args})["value"]
#
# File ~\anaconda3\envs\Imagen\Lib\site-packages\selenium\webdriver\remote\webdriver.py:447, in WebDriver.execute(self, driver_command, params)
#     445 response = self.command_executor.execute(driver_command, params)
#     446 if response:
# --> 447     self.error_handler.check_response(response)
#     448     response["value"] = self._unwrap_value(response.get("value", None))
#     449     return response
#
# File ~\anaconda3\envs\Imagen\Lib\site-packages\selenium\webdriver\remote\errorhandler.py:232, in ErrorHandler.check_response(self, response)
#     230         alert_text = value["alert"].get("text")
#     231     raise exception_class(message, screen, stacktrace, alert_text)  # type: ignore[call-arg]  # mypy is not smart enough here
# --> 232 raise exception_class(message, screen, stacktrace)
#
# JavascriptException: Message: javascript error: player is not defined
#   (Session info: chrome=136.0.7103.114)
# Stacktrace:
# 	GetHandleVerifier [0x00007FF6F3F5CF45+75717]
# 	GetHandleVerifier [0x00007FF6F3F5CFA0+75808]
# 	(No symbol) [0x00007FF6F3D28F9A]
# 	(No symbol) [0x00007FF6F3D30998]
# 	(No symbol) [0x00007FF6F3D33D51]
# 	(No symbol) [0x00007FF6F3DD05F8]
# 	(No symbol) [0x00007FF6F3DA737A]
# 	(No symbol) [0x00007FF6F3DCF39C]
# 	(No symbol) [0x00007FF6F3DA7153]
# 	(No symbol) [0x00007FF6F3D70421]
# 	(No symbol) [0x00007FF6F3D711B3]
# 	GetHandleVerifier [0x00007FF6F425D71D+3223453]
# 	GetHandleVerifier [0x00007FF6F4257CC2+3200322]
# 	GetHandleVerifier [0x00007FF6F4275AF3+3322739]
# 	GetHandleVerifier [0x00007FF6F3F76A1A+180890]
# 	GetHandleVerifier [0x00007FF6F3F7E11F+211359]
# 	GetHandleVerifier [0x00007FF6F3F65294+109332]
# 	GetHandleVerifier [0x00007FF6F3F65442+109762]
# 	GetHandleVerifier [0x00007FF6F3F4BA59+4825]
# 	BaseThreadInitThunk [0x00007FFC95957374+20]
# 	RtlUserThreadStart [0x00007FFC96B7CC91+33]

# %%
# Out:
# Collecting selenium
#   Downloading selenium-4.33.0-py3-none-any.whl.metadata (7.5 kB)
# Collecting urllib3~=2.4.0 (from urllib3[socks]~=2.4.0->selenium)
#   Downloading urllib3-2.4.0-py3-none-any.whl.metadata (6.5 kB)
# Collecting trio~=0.30.0 (from selenium)
#   Downloading trio-0.30.0-py3-none-any.whl.metadata (8.5 kB)
# Collecting trio-websocket~=0.12.2 (from selenium)
#   Downloading trio_websocket-0.12.2-py3-none-any.whl.metadata (5.1 kB)
# Collecting certifi>=2025.4.26 (from selenium)
#   Downloading certifi-2025.4.26-py3-none-any.whl.metadata (2.5 kB)
# Collecting typing_extensions~=4.13.2 (from selenium)
#   Downloading typing_extensions-4.13.2-py3-none-any.whl.metadata (3.0 kB)
# Requirement already satisfied: websocket-client~=1.8.0 in c:\users\usuario\anaconda3\envs\imagen\lib\site-packages (from selenium) (1.8.0)
# Requirement already satisfied: attrs>=23.2.0 in c:\users\usuario\anaconda3\envs\imagen\lib\site-packages (from trio~=0.30.0->selenium) (24.3.0)
# Collecting sortedcontainers (from trio~=0.30.0->selenium)
#   Downloading sortedcontainers-2.4.0-py2.py3-none-any.whl.metadata (10 kB)
# Requirement already satisfied: idna in c:\users\usuario\anaconda3\envs\imagen\lib\site-packages (from trio~=0.30.0->selenium) (3.7)
# Collecting outcome (from trio~=0.30.0->selenium)
#   Downloading outcome-1.3.0.post0-py2.py3-none-any.whl.metadata (2.6 kB)
# Requirement already satisfied: sniffio>=1.3.0 in c:\users\usuario\anaconda3\envs\imagen\lib\site-packages (from trio~=0.30.0->selenium) (1.3.0)
# Requirement already satisfied: cffi>=1.14 in c:\users\usuario\anaconda3\envs\imagen\lib\site-packages (from trio~=0.30.0->selenium) (1.17.1)
# Collecting wsproto>=0.14 (from trio-websocket~=0.12.2->selenium)
#   Downloading wsproto-1.2.0-py3-none-any.whl.metadata (5.6 kB)
# Requirement already satisfied: pysocks!=1.5.7,<2.0,>=1.5.6 in c:\users\usuario\anaconda3\envs\imagen\lib\site-packages (from urllib3[socks]~=2.4.0->selenium) (1.7.1)
# Requirement already satisfied: pycparser in c:\users\usuario\anaconda3\envs\imagen\lib\site-packages (from cffi>=1.14->trio~=0.30.0->selenium) (2.21)
# Requirement already satisfied: h11<1,>=0.9.0 in c:\users\usuario\anaconda3\envs\imagen\lib\site-packages (from wsproto>=0.14->trio-websocket~=0.12.2->selenium) (0.14.0)
# Downloading selenium-4.33.0-py3-none-any.whl (9.4 MB)
#    ---------------------------------------- 0.0/9.4 MB ? eta -:--:--
#    -------------- ------------------------- 3.4/9.4 MB 33.8 MB/s eta 0:00:01
#    ---------------------------------------- 9.4/9.4 MB 36.4 MB/s eta 0:00:00
# Downloading certifi-2025.4.26-py3-none-any.whl (159 kB)
# Downloading trio-0.30.0-py3-none-any.whl (499 kB)
# Downloading trio_websocket-0.12.2-py3-none-any.whl (21 kB)
# Downloading typing_extensions-4.13.2-py3-none-any.whl (45 kB)
# Downloading urllib3-2.4.0-py3-none-any.whl (128 kB)
# Downloading outcome-1.3.0.post0-py2.py3-none-any.whl (10 kB)
# Downloading wsproto-1.2.0-py3-none-any.whl (24 kB)
# Downloading sortedcontainers-2.4.0-py2.py3-none-any.whl (29 kB)
# Installing collected packages: sortedcontainers, wsproto, urllib3, typing_extensions, outcome, certifi, trio, trio-websocket, selenium
#   Attempting uninstall: urllib3
#     Found existing installation: urllib3 2.3.0
#     Uninstalling urllib3-2.3.0:
#       Successfully uninstalled urllib3-2.3.0
#   Attempting uninstall: typing_extensions
#     Found existing installation: typing_extensions 4.12.2
#     Uninstalling typing_extensions-4.12.2:
#       Successfully uninstalled typing_extensions-4.12.2
#   Attempting uninstall: certifi
#     Found existing installation: certifi 2025.1.31
#     Uninstalling certifi-2025.1.31:
#       Successfully uninstalled certifi-2025.1.31
# Successfully installed certifi-2025.4.26 outcome-1.3.0.post0 selenium-4.33.0 sortedcontainers-2.4.0 trio-0.30.0 trio-websocket-0.12.2 typing_extensions-4.13.2 urllib3-2.4.0 wsproto-1.2.0

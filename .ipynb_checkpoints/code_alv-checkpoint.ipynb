# %% [markdown]
# # Control de un player de vídeo a través de gestos

# %% [markdown]
# ## Paquetes necesarios

# %%
import cv2
import mediapipe as mp

# %% [markdown]
# ![Hand landmarks.]("C:/Users/34611/OneDrive/Escritorio/GTDM/Tercero/Imagen/Proyecto/Control-de-player-via-gestos/images/hand_landmarks.png")

# %%
def get_finger_states(hand_landmarks):
    fingers = []

    # Pulgar (compara X en lugar de Y porque el pulgar se mueve lateralmente)
    if hand_landmarks.landmark[4].x > hand_landmarks.landmark[3].x:
        fingers.append(1)  # Extendido
    else:
        fingers.append(0)  # Doblado

    # Resto de los dedos: Índice, Medio, Anular, Meñique
    tips = [8, 12, 16, 20]
    pips = [6, 10, 14, 18]

    for tip, pip in zip(tips, pips):
        if hand_landmarks.landmark[tip].y < hand_landmarks.landmark[pip].y:
            fingers.append(1)
        else:
            fingers.append(0)

    return fingers  # [pulgar, índice, medio, anular, meñique]

# %%
# Detecta gesto: Mano abierta o puño
def detect_custom_gesture(fingers):
    # fingers = [pulgar, índice, medio, anular, meñique]
    if fingers == [1, 1, 0, 0, 0]:
        return "L"
    elif fingers == [0, 1, 1, 0, 0]:
        return "V"
    elif fingers == [0, 1, 0, 0, 1]:
        return "Rock"
    elif fingers == [0, 0, 0, 0, 0]:
        return "Puño"
    elif fingers == [1, 1, 1, 1, 1]:
        return "Palma"
    else:
        return "Unknown"

# %%
from selenium import webdriver
from selenium.webdriver.chrome.options import Options
import time

# Configurar Selenium (modo visible o headless)
options = Options()
# options.add_argument('--headless')  # descomenta si quieres que sea invisible
options.add_argument("--autoplay-policy=no-user-gesture-required")
driver = webdriver.Chrome(options=options)
driver.get("https://areyousure.wavedash.com/player.html?content=Video1/glass_half.mpd")

from selenium.webdriver.support.ui import WebDriverWait
ready = driver.execute_script("return video.readyState;")
print("Video readyState:", ready) 
#WebDriverWait(driver, 10).until(
#    lambda d: d.execute_script("return video.readyState;") == 4
#)
# Out:
# Video readyState: 0

# %%
# Captura
import time
mp_hands   = mp.solutions.hands
mp_drawing = mp.solutions.drawing_utils
cap = cv2.VideoCapture(1)  #CAMBIAR A 0 SI NO VA
pos_anterior = None
currentMilis = 0
previousMilis = 0

with mp_hands.Hands(max_num_hands=1, min_detection_confidence=0.7) as hands:
    while cap.isOpened():
        ret, frame = cap.read()
        if not ret:
            print('No se puede leer la cámara')
            break

        try:
            image = cv2.cvtColor(frame, cv2.COLOR_BGR2RGB)
            image.flags.writeable = False
            results = hands.process(image)
            image.flags.writeable = True
            image = cv2.cvtColor(image, cv2.COLOR_RGB2BGR)

            if results.multi_hand_landmarks:
                for hand_landmarks in results.multi_hand_landmarks:
                    mp_drawing.draw_landmarks(image, hand_landmarks, mp_hands.HAND_CONNECTIONS)
                    punta_indice = hand_landmarks.landmark[8]
                    currentMilis = time.time()
                    dedos = get_finger_states(hand_landmarks)
                    mov = detect_custom_gesture(dedos) # Detecta el gesto de la palma 
                    if pos_anterior != None and currentMilis-previousMilis>0.5:
                        print('movimiento punta_indice x',punta_indice.x-pos_anterior[8].x)
                        if punta_indice.x-pos_anterior[8].x > 0.06:
                            print('adelantar')
                            mov = 'der-izq'
                            driver.execute_script("video.currentTime += 5;")
                        elif punta_indice.x-pos_anterior[8].x < -0.6:
                            print('atrasar')
                            mov = 'izq-der'
                            driver.execute_script("video.currentTime -= 5;")
                        if punta_indice.y-pos_anterior[8].y > 0.1:
                            print('subir volumen')
                            mov = 'abajo-arriba'
                            driver.execute_script("if (video.volume <= 0.9){video.volume += 0.1}else {video.volume=1};")
                        elif punta_indice.y-pos_anterior[8].y < -0.1:
                            print('bajar volumen')
                            mov = 'arriba-abajo'
                            driver.execute_script("if (video.volume >= 0.1){video.volume -= 0.1}else {video.volume=0};")
                        if mov == 'Palma':
                            print('parar')
                            driver.execute_script("video.pause();")
                        cv2.putText(image, f'Gesture: {mov}', (10, 30), cv2.FONT_HERSHEY_SIMPLEX, 1, (255, 0, 0), 2)
                        previousMilis = currentMilis
                    pos_anterior = hand_landmarks.landmark
            cv2.imshow('Hand Gesture Recognition', image)
        except Exception as e:
            import traceback
            print("Ocurrió un error:")
            traceback.print_exc()
            
        
        if cv2.waitKey(1) == ord('q'):
            break

cap.release()
cv2.destroyAllWindows()
# Out:
# movimiento punta_indice x 0.010590016841888428
# parar
# movimiento punta_indice x -0.00021386146545410156
# parar
# movimiento punta_indice x -0.005303740501403809
# parar
# movimiento punta_indice x -2.6702880859375e-05
# parar
# movimiento punta_indice x 0.007129013538360596
# bajar volumen
# movimiento punta_indice x -0.004721879959106445
# parar
# movimiento punta_indice x 0.010268568992614746
# parar
# movimiento punta_indice x 0.002995729446411133
# parar
# movimiento punta_indice x -0.004008680582046509
# parar
# movimiento punta_indice x 0.0027447938919067383
# parar
# movimiento punta_indice x -0.00010010600090026855
# movimiento punta_indice x 0.0005429983139038086
# movimiento punta_indice x -0.00047275424003601074
# movimiento punta_indice x 0.09793907403945923
# adelantar
# movimiento punta_indice x -0.017687171697616577
# movimiento punta_indice x 0.025190353393554688
# movimiento punta_indice x -0.030496329069137573
# movimiento punta_indice x 0.002521216869354248
# movimiento punta_indice x -0.05426126718521118
# movimiento punta_indice x 0.012321382761001587
# movimiento punta_indice x -0.050582289695739746
# movimiento punta_indice x -0.005314618349075317
# movimiento punta_indice x 0.392958402633667
# adelantar
# subir volumen
# movimiento punta_indice x -0.017205864191055298
# movimiento punta_indice x 0.10847711563110352
# adelantar
# movimiento punta_indice x 0.0021264851093292236
# parar
# movimiento punta_indice x -0.0005191564559936523
# parar
# movimiento punta_indice x -0.001805812120437622
# movimiento punta_indice x 0.06266248226165771
# adelantar
# movimiento punta_indice x 0.008782804012298584
# parar
# movimiento punta_indice x -0.023391544818878174
# parar
# movimiento punta_indice x -0.001601099967956543
# movimiento punta_indice x -0.03345203399658203
# parar
# movimiento punta_indice x -0.0008603334426879883
# parar
# movimiento punta_indice x -0.033178746700286865
# parar
# movimiento punta_indice x 0.009366422891616821
# movimiento punta_indice x -0.008098572492599487
# parar
# movimiento punta_indice x 0.002258121967315674
# parar
# movimiento punta_indice x 0.050579607486724854
# movimiento punta_indice x -0.013573437929153442
# movimiento punta_indice x 0.3732306957244873
# adelantar
# subir volumen
# movimiento punta_indice x -5.379319190979004e-05
# movimiento punta_indice x -0.07734954357147217
# atrasar
# bajar volumen
# movimiento punta_indice x -0.0072762370109558105
# movimiento punta_indice x -0.4175751209259033
# atrasar
# bajar volumen
# movimiento punta_indice x 0.00455552339553833
# movimiento punta_indice x -0.032157063484191895
# movimiento punta_indice x 0.0004507601261138916
# movimiento punta_indice x 0.02570950984954834
# movimiento punta_indice x 0.002782881259918213
# movimiento punta_indice x 0.0014060139656066895
# movimiento punta_indice x -0.002995908260345459
# movimiento punta_indice x 0.016600221395492554
# movimiento punta_indice x -0.002100825309753418
# movimiento punta_indice x -0.01702803373336792
# movimiento punta_indice x -0.018411636352539062
# movimiento punta_indice x -0.021589279174804688
# movimiento punta_indice x -0.02344900369644165
# movimiento punta_indice x -0.018771246075630188
# movimiento punta_indice x -0.015192031860351562
# movimiento punta_indice x -0.02603250741958618
# movimiento punta_indice x -0.0028651952743530273
# movimiento punta_indice x 0.002827465534210205
# movimiento punta_indice x -0.02754795551300049
# movimiento punta_indice x -0.010954022407531738
# movimiento punta_indice x 0.0029482245445251465
# movimiento punta_indice x -0.0015400052070617676
# movimiento punta_indice x 0.4176417291164398
# adelantar
# subir volumen
# movimiento punta_indice x -0.011447727680206299
# movimiento punta_indice x -0.010446399450302124
# movimiento punta_indice x -0.00784146785736084
# movimiento punta_indice x 0.43345317244529724
# adelantar
# subir volumen
# movimiento punta_indice x -0.015478193759918213
# movimiento punta_indice x -0.024205893278121948
# movimiento punta_indice x -0.00407804548740387
# movimiento punta_indice x 0.0058553218841552734
# movimiento punta_indice x 0.004258692264556885
# movimiento punta_indice x -0.007066905498504639
# movimiento punta_indice x -0.018177807331085205
# movimiento punta_indice x 0.0018594861030578613
# movimiento punta_indice x -0.0016916394233703613
# movimiento punta_indice x -0.020341813564300537
# movimiento punta_indice x 0.019820302724838257
# movimiento punta_indice x -0.026701003313064575
# movimiento punta_indice x 0.0021672695875167847
# movimiento punta_indice x 0.00574803352355957
# movimiento punta_indice x -0.04671138525009155
# movimiento punta_indice x -0.008676186203956604

# %%
# Reproducir
driver.execute_script("video.play();")
# Out:
# Video readyState: 0
